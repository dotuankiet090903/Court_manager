# %% [markdown]
# <a href="https://colab.research.google.com/github/dotuankiet992003/Court_manager/blob/main/Final_MachineLearning_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Member's names:
# - Đỗ Tuấn Kiệt
# - Đặng Cao Đạt

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Part 1

# %% [markdown]
# ### Statiscal Analysis

# %%
from keras.models import Sequential
import tensorflow as tf
from keras.preprocessing import image
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
import gdown
import random
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
gdown.download('https://drive.google.com/uc?id=1ZYdt0zN4LjWqP3cQDblNhXjeohcryY5H',
                'Womens Clothing E-Commerce Reviews.csv',
                quiet=False)

# %%
# Load the dataset
data_df = pd.read_csv('Womens Clothing E-Commerce Reviews.csv', index_col=0)

data_df.head()
# Out:
#    Clothing ID  Age                    Title  \
# 0          767   33                      NaN
# 1         1080   34                      NaN
# 2         1077   60  Some major design flaws
# 3         1049   50         My favorite buy!
# 4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
# Perform statistical analysis
# Get the summary statistics of the dataframe
summary = data_df.describe()

# Print the summary statistics
print(summary)
# Out:
#         Clothing ID           Age        Rating  Recommended IND  \
# count  23486.000000  23486.000000  23486.000000     23486.000000
# mean     918.118709     43.198544      4.196032         0.822362
# std      203.298980     12.279544      1.110031         0.382216
# min        0.000000     18.000000      1.000000         0.000000
# 25%      861.000000     34.000000      4.000000         1.000000
# 50%      936.000000     41.000000      5.000000         1.000000
# 75%     1078.000000     52.000000      5.000000         1.000000
# max     1205.000000     99.000000      5.000000         1.000000
#
#        Positive Feedback Count
# count             23486.000000
# mean                  2.535936
# std                   5.702202
# min                   0.000000
# 25%                   0.000000
# 50%                   1.000000
# 75%                   3.000000
# max                 122.000000

# %%
# Creating graphs for visualization
# Loop through all columns in the DataFrame
for column in data_df.columns:
    # Check if the column data type is numeric
    if pd.api.types.is_numeric_dtype(data_df[column]):
        # Create a histogram for the column
        plt.hist(data_df[column].dropna())
        plt.title(f'Histogram of {column}')
        plt.show()
    else:
        print(f'Skipped {column} due to non-numeric data')

# Create a correlation heatmap after looping through all features
sns.heatmap(data_df.corr(), annot=True)
plt.show()
# Out:
# Skipped Title due to non-numeric data
# Skipped Review Text due to non-numeric data
# Skipped Division Name due to non-numeric data
# Skipped Department Name due to non-numeric data
# Skipped Class Name due to non-numeric data
# <ipython-input-32-774a0cac6aad>:14: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_df.corr(), annot=True)

# %% [markdown]
# ### Explanation of Feature Importance in Predicting Ratings (Investigate role of features)

# %%
# First, calculate the split sizes. 80% training, 10% validation, 10% test.
train_size = int(0.8 * len(data_df))
val_size = int(0.1 * len(data_df))
test_size = len(data_df) - (train_size + val_size)

# Sanity check the sizes.
assert((train_size + val_size + test_size) == len(data_df))

# Create a list of indeces for all of the samples in the dataset.
indeces = np.arange(0, len(data_df))

# Shuffle the indeces randomly.
random.shuffle(indeces)

# Get a list of indeces for each of the splits.
train_idx = indeces[0:train_size]
val_idx = indeces[train_size:(train_size + val_size)]
test_idx = indeces[(train_size + val_size):]

# Sanity check
assert(len(train_idx) == train_size)
assert(len(test_idx) == test_size)

# With these lists, we can now select the corresponding dataframe rows using,
# e.g., train_df = data_df.iloc[train_idx]

print('  Training size: {:,}'.format(train_size))
print('Validation size: {:,}'.format(val_size))
print('      Test size: {:,}'.format(test_size))
# Out:
#   Training size: 18,788
# Validation size: 2,348
#       Test size: 2,350

# %%
# Remove non-numberical data
df_vis = data_df.drop(columns=["Title", "Review Text", "Division Name", "Department Name", "Class Name"])

# %%
# Rating Feature
X = df_vis.drop('Rating', axis=1)
y = df_vis['Rating']

# Create a Random Forest Regressor model
model = RandomForestRegressor()

# Fit the model
model.fit(X, y)

# Get feature importance
importance = model.feature_importances_

# Create a DataFrame for feature importances
df_importance = pd.DataFrame({'Feature': X.columns, 'Importance': importance})

# Sort the DataFrame by importance
df_importance = df_importance.sort_values('Importance', ascending=False)

# Plot the feature importances as a horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=df_importance, orient='h', color='skyblue')
plt.title('Rating Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.show()

# %%
# Recommended IND Feature
X = df_vis.drop('Recommended IND', axis=1)
y = df_vis['Recommended IND']

# Fit the model
model.fit(X, y)

# Get feature importance
importance = model.feature_importances_

# Create a DataFrame for feature importances
df_importance = pd.DataFrame({'Feature': X.columns, 'Importance': importance})

# Sort the DataFrame by importance
df_importance = df_importance.sort_values('Importance', ascending=False)

# Plot the feature importances as a horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=df_importance, orient='h',  color='skyblue')
plt.title('Recommended IND Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.show()

# %%
# Positive Feedback Count Feature
X = df_vis.drop('Positive Feedback Count', axis=1)
y = df_vis['Positive Feedback Count']

# Fit the model
model.fit(X, y)

# Get feature importance
importance = model.feature_importances_

# Create a DataFrame for feature importances
df_importance = pd.DataFrame({'Feature': X.columns, 'Importance': importance})

# Sort the DataFrame by importance
df_importance = df_importance.sort_values('Importance', ascending=False)

# Plot the feature importances as a horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=df_importance, orient='h', color='skyblue')
plt.title('Positive Feedback Count Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.show()

# %%
# First, change the type of the specified columns to "category". This will
# assign a "code" to each unique category value.
data_df["Clothing ID"] = data_df["Clothing ID"].astype('category')
data_df["Division Name"] = data_df["Division Name"].astype('category')
data_df["Department Name"] = data_df["Department Name"].astype('category')
data_df["Class Name"] = data_df["Class Name"].astype('category')

# Second, replace the strings with their code values.
data_df["Clothing ID"] = data_df["Clothing ID"].cat.codes
data_df["Division Name"] = data_df["Division Name"].cat.codes
data_df["Department Name"] = data_df["Department Name"].cat.codes
data_df["Class Name"] = data_df["Class Name"].cat.codes

# %%
# Cast the numerical features to floats.
data_df["Age"] = data_df["Age"].astype('float')
data_df["Rating"] = data_df["Rating"].astype('float')
data_df["Positive Feedback Count"] = data_df["Positive Feedback Count"].astype('float')

data_df.head()
# Out:
#    Clothing ID   Age                    Title  \
# 0          767  33.0                      NaN
# 1         1080  34.0                      NaN
# 2         1077  60.0  Some major design flaws
# 3         1049  50.0         My favorite buy!
# 4          847  47.0         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...     4.0                1
# 1  Love this dress!  it's sooo pretty.  i happene...     5.0                1
# 2  I had such high hopes for this dress and reall...     3.0                0
# 3  I love, love, love this jumpsuit. it's fun, fl...     5.0                1
# 4  This shirt is very flattering to all due to th...     5.0                1
#
#    Positive Feedback Count  Division Name  Department Name  Class Name
# 0                      0.0              2                2           5
# 1                      4.0              0                1           3
# 2                      0.0              0                1           3
# 3                      0.0              1                0          13
# 4                      6.0              0                4           0

# %%
# Retrieve the labels for each of the splits.
y_train = data_df["Recommended IND"].iloc[train_idx]
y_val = data_df["Recommended IND"].iloc[val_idx]
y_test = data_df["Recommended IND"].iloc[test_idx]

# Before selecting the inputs, remove text columns and the labels.
data_df = data_df.drop(columns=["Clothing ID","Title", "Review Text"])

# Select the inputs for the different splits.
X_train = data_df.iloc[train_idx]
X_val = data_df.iloc[val_idx]
X_test = data_df.iloc[test_idx]

X_train.head()
# Out:
#         Age  Rating  Recommended IND  Positive Feedback Count  Division Name  \
# 20246  59.0     5.0                1                      9.0              1
# 11853  30.0     5.0                1                      0.0              0
# 7813   41.0     3.0                1                      0.0              1
# 10220  30.0     5.0                1                      0.0              0
# 454    39.0     5.0                1                      2.0              0
#
#        Department Name  Class Name
# 20246                3           6
# 11853                0          13
# 7813                 4           8
# 10220                1           3
# 454                  4           8

# %% [markdown]
# ## Part 2

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# Scale your data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# List of models
models = [
    ("Linear Regression", LinearRegression()),
    ("Decision Tree", DecisionTreeRegressor()),
    ("KNN", KNeighborsRegressor()),
    ("Naive Bayes", GaussianNB()),
    ("Logistic Regression", LogisticRegression(max_iter=1000)),  # Increase max_iter
    ("SVM", SVR())
]

# Apply each model
for name, model in models:
    # Fit the model
    model.fit(X_train_scaled, y_train)  # Use scaled data

    # Make predictions on the training set
    y_pred_train = model.predict(X_train_scaled)  # Use scaled data

    # Calculate the mean squared error on the training set
    mse_train = mean_squared_error(y_train, y_pred_train)

    # Print the MSE for the training set
    print(f"{name} Training MSE: {mse_train}")

    # Make predictions on the validation set
    y_pred_val = model.predict(X_val_scaled)  # Use scaled data

    # Calculate the mean squared error on the validation set
    mse_val = mean_squared_error(y_val, y_pred_val)

    # Print the MSE for the validation set
    print(f"{name} Validation MSE: {mse_val}")
# Out:
# Linear Regression Training MSE: 1.2549108576787126e-30
# Linear Regression Validation MSE: 1.1756375088123243e-30
# Decision Tree Training MSE: 0.0
# Decision Tree Validation MSE: 0.0
# KNN Training MSE: 6.812859271875665e-05
# KNN Validation MSE: 0.0
# Naive Bayes Training MSE: 0.0
# Naive Bayes Validation MSE: 0.0
# Logistic Regression Training MSE: 0.0
# Logistic Regression Validation MSE: 0.0
# SVM Training MSE: 0.00243346188351267
# SVM Validation MSE: 0.00256466359707169

# %%
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# List of models
models = [
    ("Random Forest (Bagging)", RandomForestRegressor()),
    ("AdaBoost (Boosting)", AdaBoostRegressor()),
    ("Gradient Boosting (Boosting)", GradientBoostingRegressor())
]

# Apply each model
for name, model in models:
    # Scale data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)

    # Fit the model
    model.fit(X_train_scaled, y_train)  # Use scaled data

    # Make predictions on the training set
    y_train_pred = model.predict(X_train_scaled)

    # Calculate the mean squared error on the training set
    mse_train = mean_squared_error(y_train, y_train_pred)

    # Print the MSE for the training set
    print(f"{name} Training MSE: {mse_train}")
# Out:
# Random Forest (Bagging) Training MSE: 0.0
# AdaBoost (Boosting) Training MSE: 0.0
# Gradient Boosting (Boosting) Training MSE: 1.039684909411618e-10

# %% [markdown]
# ## Part 3

# %%
print(X_train_scaled.shape)
# Out:
# (18788, 7)

# %%
print(X_train_scaled)
# Out:
# [[ 1.28827931  0.72352661  0.46794337 ...  0.86076155  0.39539538
#   -0.17654574]
#  [-1.06853038  0.72352661  0.46794337 ... -0.76915057 -1.43930167
#    1.17016211]
#  [-0.17456808 -1.06510733  0.46794337 ...  0.86076155  1.00696106
#    0.20822793]
#  ...
#  [ 1.8571644   0.72352661  0.46794337 ... -0.76915057  1.00696106
#    0.20822793]
#  [-0.58091458  0.72352661  0.46794337 ...  2.49067367 -0.21617031
#    0.40061477]
#  [-1.39360757  0.72352661  0.46794337 ...  0.86076155  1.00696106
#    0.20822793]]

# %% [markdown]
# ### FFNN

# %%
from keras.models import Sequential
from keras.layers import Dense
#Feed Forward Neural Network
model = Sequential()
model.add(Dense(X_train.shape[0], input_dim=X_train.shape[1], activation='relu'))  # Input layer
model.add(Dense(64, activation='relu'))  # Hidden layer
model.add(Dense(1, activation='sigmoid'))  # Output layer

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 588/588 [==============================] - 23s 36ms/step - loss: 0.0782 - accuracy: 0.9742 - val_loss: 7.0295e-04 - val_accuracy: 1.0000
# Epoch 2/10
# 588/588 [==============================] - 17s 29ms/step - loss: 2.2534e-04 - accuracy: 1.0000 - val_loss: 4.9061e-05 - val_accuracy: 1.0000
# Epoch 3/10
# 588/588 [==============================] - 17s 29ms/step - loss: 0.0457 - accuracy: 0.9948 - val_loss: 0.0114 - val_accuracy: 0.9974
# Epoch 4/10
# 588/588 [==============================] - 17s 29ms/step - loss: 9.1984e-04 - accuracy: 0.9999 - val_loss: 3.9327e-05 - val_accuracy: 1.0000
# Epoch 5/10
# 588/588 [==============================] - 17s 28ms/step - loss: 1.9416e-05 - accuracy: 1.0000 - val_loss: 8.3919e-06 - val_accuracy: 1.0000
# Epoch 6/10
# 588/588 [==============================] - 22s 37ms/step - loss: 4.7368e-06 - accuracy: 1.0000 - val_loss: 2.7183e-06 - val_accuracy: 1.0000
# Epoch 7/10
# 588/588 [==============================] - 17s 28ms/step - loss: 1.7242e-06 - accuracy: 1.0000 - val_loss: 7.6423e-07 - val_accuracy: 1.0000
# Epoch 8/10
# 588/588 [==============================] - 16s 28ms/step - loss: 4.2386e-07 - accuracy: 1.0000 - val_loss: 2.6422e-07 - val_accuracy: 1.0000
# Epoch 9/10
# 588/588 [==============================] - 16s 26ms/step - loss: 1.9363e-07 - accuracy: 1.0000 - val_loss: 1.4943e-07 - val_accuracy: 1.0000
# Epoch 10/10
# 588/588 [==============================] - 15s 26ms/step - loss: 1.1829e-07 - accuracy: 1.0000 - val_loss: 9.8140e-08 - val_accuracy: 1.0000

# %%
y_pred_ffnn = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred_ffnn)
print("MSE of Feed Forward Neural Network", mse)
# Out:
# 74/74 [==============================] - 0s 5ms/step
# MSE of Feed Forward Neural Network 7.899077084811746e-14

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], c='b', label = 'Train Loss')
plt.plot(history.history['val_loss'], c='r', label = 'Validation Loss')
plt.legend()
plt.grid()
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.show()

# %% [markdown]
# ### RNN

# %%
#Recurrent Neural Network
from keras.layers import SimpleRNN
model = Sequential()
model.add(SimpleRNN(50, activation='relu', input_shape=(X_train.shape[1], 1), return_sequences=True))  # RNN layer
model.add(SimpleRNN(50, activation='relu'))  # Second RNN layer
model.add(Dense(1))  # Output layer

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=20, verbose=0, validation_data = (X_val, y_val))

# %%
y_pred_rnn = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred_rnn)
print("MSE of Recurrent Neural Network", mse)
# Out:
# 74/74 [==============================] - 0s 3ms/step
# MSE of Recurrent Neural Network 0.00010064798197994518

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], c='b', label = 'Train Loss')
plt.plot(history.history['val_loss'], c='r', label = 'Validation Loss')
plt.legend()
plt.grid()
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.show()

# %% [markdown]
# ## Part 4

# %% [markdown]
# ### Applying overfitting prevention technique

# %%
#Overfitting prevention technique

from keras.layers import Dropout
from keras.regularizers import l2
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization

#FFNN

# Initialize the constructor
model = Sequential()

# Add an input layer with L2 regularization
model.add(Dense(X_train.shape[0], activation='relu', input_dim=7, kernel_regularizer=l2(0.01)))

# Add a hidden layer with dropout
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

# Add batch normalization layer
model.add(BatchNormalization())

# Add an output layer
model.add(Dense(1, activation='sigmoid'))

# Set up early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val), callbacks=[es])
# Out:
# Epoch 1/50
# 588/588 [==============================] - 22s 35ms/step - loss: 0.3797 - accuracy: 0.8547 - val_loss: 0.1531 - val_accuracy: 0.9744
# Epoch 2/50
# 588/588 [==============================] - 17s 28ms/step - loss: 0.2339 - accuracy: 0.9248 - val_loss: 0.5045 - val_accuracy: 0.7653
# Epoch 3/50
# 588/588 [==============================] - 18s 31ms/step - loss: 0.0906 - accuracy: 0.9845 - val_loss: 1.1013 - val_accuracy: 0.4736
# Epoch 4/50
# 588/588 [==============================] - 19s 33ms/step - loss: 0.1033 - accuracy: 0.9787 - val_loss: 0.0774 - val_accuracy: 0.9945
# Epoch 5/50
# 588/588 [==============================] - 18s 31ms/step - loss: 0.0776 - accuracy: 0.9865 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 6/50
# 588/588 [==============================] - 17s 29ms/step - loss: 0.0595 - accuracy: 0.9902 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 7/50
# 588/588 [==============================] - 17s 29ms/step - loss: 0.0536 - accuracy: 0.9914 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 8/50
# 588/588 [==============================] - 17s 29ms/step - loss: 0.0560 - accuracy: 0.9911 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 9/50
# 588/588 [==============================] - 18s 30ms/step - loss: 0.0562 - accuracy: 0.9898 - val_loss: 0.0440 - val_accuracy: 0.9979
# Epoch 10/50
# 588/588 [==============================] - 18s 31ms/step - loss: 0.0391 - accuracy: 0.9946 - val_loss: 0.0856 - val_accuracy: 0.9732
# Epoch 11/50
# 588/588 [==============================] - 18s 31ms/step - loss: 0.0616 - accuracy: 0.9896 - val_loss: 0.0310 - val_accuracy: 0.9970
# Epoch 12/50
# 588/588 [==============================] - 17s 29ms/step - loss: 0.0718 - accuracy: 0.9872 - val_loss: 0.0318 - val_accuracy: 0.9996
# Epoch 13/50
# 588/588 [==============================] - 17s 29ms/step - loss: 0.0450 - accuracy: 0.9943 - val_loss: 0.0217 - val_accuracy: 0.9996
# Epoch 14/50
# 588/588 [==============================] - 18s 30ms/step - loss: 0.0510 - accuracy: 0.9911 - val_loss: 0.0273 - val_accuracy: 0.9983
# Epoch 15/50
# 588/588 [==============================] - 17s 30ms/step - loss: 0.0397 - accuracy: 0.9943 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 16/50
# 588/588 [==============================] - 17s 30ms/step - loss: 0.0572 - accuracy: 0.9903 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 17/50
# 588/588 [==============================] - 19s 31ms/step - loss: 0.0355 - accuracy: 0.9946 - val_loss: 0.0156 - val_accuracy: 0.9996
# Epoch 18/50
# 588/588 [==============================] - 17s 29ms/step - loss: 0.0414 - accuracy: 0.9931 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 19/50
# 588/588 [==============================] - 19s 33ms/step - loss: 0.0364 - accuracy: 0.9939 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 20/50
# 588/588 [==============================] - 17s 29ms/step - loss: 0.0447 - accuracy: 0.9930 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 21/50
# 588/588 [==============================] - 19s 32ms/step - loss: 0.0359 - accuracy: 0.9950 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 22/50
# 588/588 [==============================] - 21s 36ms/step - loss: 0.0337 - accuracy: 0.9955 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 23/50
# 588/588 [==============================] - 20s 34ms/step - loss: 0.0585 - accuracy: 0.9898 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 24/50
# 588/588 [==============================] - 19s 32ms/step - loss: 0.0314 - accuracy: 0.9956 - val_loss: 0.0223 - val_accuracy: 0.9991
# Epoch 25/50
# 588/588 [==============================] - 20s 34ms/step - loss: 0.0318 - accuracy: 0.9953 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 26/50
# 588/588 [==============================] - 20s 34ms/step - loss: 0.0330 - accuracy: 0.9954 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 27/50
# 588/588 [==============================] - 20s 35ms/step - loss: 0.0286 - accuracy: 0.9963 - val_loss: 0.0178 - val_accuracy: 0.9983
# Epoch 28/50
# 588/588 [==============================] - 19s 33ms/step - loss: 0.0460 - accuracy: 0.9936 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 29/50
# 588/588 [==============================] - 19s 33ms/step - loss: 0.0272 - accuracy: 0.9951 - val_loss: 0.0185 - val_accuracy: 0.9987
# Epoch 30/50
# 588/588 [==============================] - 19s 33ms/step - loss: 0.0281 - accuracy: 0.9948 - val_loss: 0.0414 - val_accuracy: 0.9949
# Epoch 31/50
# 588/588 [==============================] - 18s 31ms/step - loss: 0.0323 - accuracy: 0.9954 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 32/50
# 588/588 [==============================] - 19s 32ms/step - loss: 0.0372 - accuracy: 0.9941 - val_loss: 0.0669 - val_accuracy: 0.9821
# Epoch 33/50
# 588/588 [==============================] - 18s 31ms/step - loss: 0.2059 - accuracy: 0.9556 - val_loss: 0.2197 - val_accuracy: 0.8880
# Epoch 34/50
# 588/588 [==============================] - 20s 33ms/step - loss: 0.3164 - accuracy: 0.9128 - val_loss: 0.1426 - val_accuracy: 0.9996
# Epoch 35/50
# 588/588 [==============================] - 18s 30ms/step - loss: 0.3946 - accuracy: 0.8677 - val_loss: 0.4652 - val_accuracy: 0.8301
# Epoch 36/50
# 588/588 [==============================] - 19s 33ms/step - loss: 0.4773 - accuracy: 0.8204 - val_loss: 0.4642 - val_accuracy: 0.8301
# Epoch 37/50
# 588/588 [==============================] - 20s 34ms/step - loss: 0.4750 - accuracy: 0.8204 - val_loss: 0.4602 - val_accuracy: 0.8301
# Epoch 38/50
# 588/588 [==============================] - 19s 32ms/step - loss: 0.4740 - accuracy: 0.8204 - val_loss: 0.4582 - val_accuracy: 0.8301
# Epoch 38: early stopping

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], c='b', label = 'Train Loss')
plt.plot(history.history['val_loss'], c='r', label = 'Validation Loss')
plt.legend()
plt.grid()
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.show()

# %%
#Recurrent Neural Networks

# Initialize the constructor
model = Sequential()

# Add an input layer with L2 regularization
model.add(SimpleRNN(64, activation='tanh', input_shape=(X_train.shape[1], 1), return_sequences=True, kernel_regularizer=l2(0.01)))

# Add a hidden layer with dropout
model.add(SimpleRNN(50, activation='relu'))  # Second RNN layer
model.add(Dropout(0.5))

# Add batch normalization layer
model.add(BatchNormalization())

# Add an output layer
model.add(Dense(1, activation='sigmoid'))

# Set up early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_data=(X_val_scaled, y_val), callbacks=[es])
# Out:
# Epoch 1/50
# 588/588 [==============================] - 9s 10ms/step - loss: 0.0730 - accuracy: 0.9859 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 2/50
# 588/588 [==============================] - 5s 8ms/step - loss: 0.0082 - accuracy: 0.9992 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 3/50
# 588/588 [==============================] - 6s 10ms/step - loss: 0.0046 - accuracy: 0.9991 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 4/50
# 588/588 [==============================] - 8s 13ms/step - loss: 0.0095 - accuracy: 0.9980 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 5/50
# 588/588 [==============================] - 5s 8ms/step - loss: 0.0053 - accuracy: 0.9993 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 6/50
# 588/588 [==============================] - 6s 11ms/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 7/50
# 588/588 [==============================] - 5s 8ms/step - loss: 0.0018 - accuracy: 0.9999 - val_loss: 8.6033e-04 - val_accuracy: 1.0000
# Epoch 8/50
# 588/588 [==============================] - 5s 8ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 9/50
# 588/588 [==============================] - 6s 10ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 10/50
# 588/588 [==============================] - 6s 9ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 11/50
# 588/588 [==============================] - 6s 9ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 12/50
# 588/588 [==============================] - 5s 9ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 5.7190e-04 - val_accuracy: 1.0000
# Epoch 13/50
# 588/588 [==============================] - 5s 8ms/step - loss: 8.1210e-04 - accuracy: 0.9999 - val_loss: 4.4159e-04 - val_accuracy: 1.0000
# Epoch 14/50
# 588/588 [==============================] - 6s 11ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 15/50
# 588/588 [==============================] - 5s 9ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 16/50
# 588/588 [==============================] - 6s 10ms/step - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.1154 - val_accuracy: 0.9685
# Epoch 17/50
# 588/588 [==============================] - 6s 10ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 8.4830e-04 - val_accuracy: 1.0000
# Epoch 18/50
# 588/588 [==============================] - 9s 16ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 19/50
# 588/588 [==============================] - 5s 9ms/step - loss: 0.0016 - accuracy: 0.9999 - val_loss: 7.6038e-04 - val_accuracy: 1.0000
# Epoch 20/50
# 588/588 [==============================] - 5s 9ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 5.5650e-04 - val_accuracy: 1.0000
# Epoch 21/50
# 588/588 [==============================] - 6s 10ms/step - loss: 9.1655e-04 - accuracy: 0.9999 - val_loss: 3.1569e-04 - val_accuracy: 1.0000
# Epoch 22/50
# 588/588 [==============================] - 4s 7ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 8.6157e-04 - val_accuracy: 1.0000
# Epoch 23/50
# 588/588 [==============================] - 4s 7ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 6.2641e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 588/588 [==============================] - 6s 10ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0616 - val_accuracy: 0.9779
# Epoch 25/50
# 588/588 [==============================] - 5s 8ms/step - loss: 0.0056 - accuracy: 0.9991 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 26/50
# 588/588 [==============================] - 5s 9ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 27/50
# 588/588 [==============================] - 6s 10ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 9.3762e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 588/588 [==============================] - 5s 8ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 6.9957e-04 - val_accuracy: 1.0000
# Epoch 29/50
# 588/588 [==============================] - 6s 10ms/step - loss: 6.9274e-04 - accuracy: 1.0000 - val_loss: 4.7881e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 588/588 [==============================] - 4s 7ms/step - loss: 5.6498e-04 - accuracy: 0.9999 - val_loss: 3.4682e-04 - val_accuracy: 1.0000
# Epoch 31/50
# 588/588 [==============================] - 5s 8ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 32/50
# 588/588 [==============================] - 6s 9ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 9.0789e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 588/588 [==============================] - 4s 8ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 5.6492e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 588/588 [==============================] - 4s 7ms/step - loss: 7.6224e-04 - accuracy: 0.9999 - val_loss: 3.9354e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 588/588 [==============================] - 6s 10ms/step - loss: 5.2840e-04 - accuracy: 1.0000 - val_loss: 3.3859e-04 - val_accuracy: 1.0000
# Epoch 36/50
# 588/588 [==============================] - 5s 8ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 9.5348e-04 - val_accuracy: 1.0000
# Epoch 37/50
# 588/588 [==============================] - 6s 10ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 5.0634e-04 - val_accuracy: 1.0000
# Epoch 38/50
# 588/588 [==============================] - 5s 9ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 2.7941e-04 - val_accuracy: 1.0000
# Epoch 39/50
# 588/588 [==============================] - 5s 8ms/step - loss: 9.6868e-04 - accuracy: 0.9998 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 40/50
# 588/588 [==============================] - 6s 10ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 8.4886e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 588/588 [==============================] - 5s 8ms/step - loss: 9.3726e-04 - accuracy: 0.9999 - val_loss: 5.8404e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 588/588 [==============================] - 4s 8ms/step - loss: 9.0095e-04 - accuracy: 0.9999 - val_loss: 4.8175e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 588/588 [==============================] - 6s 10ms/step - loss: 0.0071 - accuracy: 0.9988 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 44/50
# 588/588 [==============================] - 5s 8ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 45/50
# 588/588 [==============================] - 6s 11ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 8.5099e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 588/588 [==============================] - 5s 8ms/step - loss: 9.0210e-04 - accuracy: 1.0000 - val_loss: 7.1142e-04 - val_accuracy: 1.0000
# Epoch 47/50
# 588/588 [==============================] - 5s 8ms/step - loss: 7.9509e-04 - accuracy: 1.0000 - val_loss: 5.6169e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 588/588 [==============================] - 6s 10ms/step - loss: 8.8347e-04 - accuracy: 0.9999 - val_loss: 4.6916e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 588/588 [==============================] - 4s 7ms/step - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 50/50
# 588/588 [==============================] - 4s 7ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 8.7339e-04 - val_accuracy: 1.0000

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], c='b', label = 'Train Loss')
plt.plot(history.history['val_loss'], c='r', label = 'Validation Loss')
plt.legend()
plt.grid()
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Loss', fontsize=20)
plt.show()

# %% [markdown]
# Linear Regression: You can add a regularization term to the loss function to prevent overfitting. In sklearn, you can use Ridge for L2 regularization or Lasso for L1 regularization.
#
# Decision Tree: You can limit the depth of the tree (max_depth), set a minimum number of samples required to split an internal node (min_samples_split), or set a minimum number of samples required to be at a leaf node (min_samples_leaf) to prevent overfitting.
#
# KNN: Choosing the right value for k is crucial to prevent overfitting. Cross-validation can be helpful to find the optimal k.
#
# Naive Bayes: Naive Bayes is less prone to overfitting compared to other models. However, you can still use cross-validation to tune the parameters.
#
# Logistic Regression: Similar to Linear Regression, you can add a regularization term to the loss function to prevent overfitting. In sklearn, you can adjust the C parameter which is the inverse of regularization strength.
#
# SVM: You can use the C parameter to control the trade-off between achieving a low error on the training data and minimizing the norm of the weights. A smaller C creates a wider margin but allows more misclassifications.

# %%
#Random Forest Regressor (Ensemble Learning)
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [10, 20, 30, 40, 50],
    'min_samples_leaf': [1, 2, 4, 6, 8],
}

rf = RandomForestRegressor()
grid_search_rf = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5)
history = grid_search_rf.fit(X_train, y_train)

# %%
param_grid = {
    'n_estimators': [50, 100, 200]
}

ab = AdaBoostRegressor()
grid_search_ada = GridSearchCV(estimator=ab, param_grid=param_grid, cv=5)
grid_search_ada.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostRegressor(),
#              param_grid={'n_estimators': [50, 100, 200]})

# %%
#Gradient Boosting Regressor
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1]
}

gb = GradientBoostingRegressor()
grid_search_gb = GridSearchCV(estimator=gb, param_grid=param_grid, cv=5)
grid_search_gb.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 1],
#                          'n_estimators': [50, 100, 200]})

# %%
from sklearn.metrics import roc_curve, auc
# Compute ROC curve and ROC area for Random Forest
rf_pred = grid_search_rf.predict(X_test)
rf_fpr, rf_tpr, _ = roc_curve(y_test, rf_pred)
rf_roc_auc = auc(rf_fpr, rf_tpr)

# Compute ROC curve and ROC area for AdaBoost
ab_pred = grid_search_ada.predict(X_test)
ab_fpr, ab_tpr, _ = roc_curve(y_test, ab_pred)
ab_roc_auc = auc(ab_fpr, ab_tpr)

# Compute ROC curve and ROC area for AdaBoost
gb_pred = grid_search_gb.predict(X_test)
gb_fpr, gb_tpr, _ = roc_curve(y_test, gb_pred)
gb_roc_auc = auc(gb_fpr, gb_tpr)


plt.figure()
plt.plot(rf_fpr, rf_tpr, label='Random Forest (area = %0.2f)' % rf_roc_auc)
plt.plot(ab_fpr, ab_tpr, label='AdaBoost (area = %0.2f)' % ab_roc_auc)
plt.plot(gb_fpr, gb_tpr, label='GradBoost (area = %0.2f)' % gb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Part 5

# %% [markdown]
# **Here is our result before apply overfitting technique:**
#
# MSE of Recurrent Neural Network 0.00031522816255823925
#
# MSE of Feed Forward Neural Network 0.24184707239558825
#
# Random Forest (Bagging) Training MSE: 0.0
#
# AdaBoost (Boosting) Training MSE: 0.0
#
# Gradient Boosting (Boosting) Training MSE: 1.0290598273633982e-10
#
# Linear Regression Training MSE: 7.03664357828884e-32
#
# Decision Tree Training MSE: 0.0
#
# KNN Training MSE: 5.748350010645093e-05
#
# Naive Bayes Training MSE: 0.0
#
# Logistic Regression Training MSE: 0.0
#
# SVM Training MSE: 0.0024173057232355975

# %% [markdown]
# #### Analysis Result

# %% [markdown]
# The Mean Squared Error (MSE) is a measure of how close a fitted line is to data points. The smaller the MSE, the closer the fit is to the data. In other words, the smaller the number, the better the model has performed.
#
# Recurrent Neural Network (RNN): The MSE is very small, which indicates that this model has performed well.
#
# Feed Forward Neural Network (FFNN): The MSE is larger compared to the RNN, which suggests that this model is not as good as RNN.
#
# Random Forest, AdaBoost, Decision Tree, Naive Bayes, Logistic Regression: The training MSE for these models is 0, which might suggest that they are overfitting the training data. Overfitting happens when a model learns the detail and noise in the training data to the extent that it negatively impacts the performance of the model on new data.
#
# Gradient Boosting: The training MSE is extremely small, almost zero, which is a good sign. But it might be a sign of overfitting.
#
# Linear Regression: The training and validation MSEs are extremely small, which suggests that this model has performed very well on both the training data and the validation data.
#
# K-Nearest Neighbors (KNN): The training and validation MSEs are small, but not as small as some of the other models. This suggests that the model is performing reasonably well, but there might be room for improvement.
#
# Support Vector Machine (SVM): The training and validation MSEs are larger than some of the other models, which suggests that this model might not be performing as well.

# %% [markdown]
# #### Improving Accuracy

# %% [markdown]
# The following code is to increase accuracy some of the result of our models

# %% [markdown]
# ##### Decision Tree

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid = {'max_depth': range(1, 21), 'min_samples_split': range(2, 21), 'min_samples_leaf': range(1, 21)}

tree = DecisionTreeRegressor()

grid = GridSearchCV(tree, param_grid, cv=10, scoring='neg_mean_squared_error')
grid.fit(X_train_scaled, y_train)

print(f"Best parameters for Decision Tree: {grid.best_params_}")

best_tree = grid.best_estimator_

# %% [markdown]
# ##### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

param_grid = {'var_smoothing': np.logspace(0,-9, num=100)}

nb = GaussianNB()

grid = GridSearchCV(nb, param_grid, cv=10, scoring='neg_mean_squared_error')
grid.fit(X_train_scaled, y_train)

print(f"Best parameters for Naive Bayes: {grid.best_params_}")

best_nb = grid.best_estimator_

# %% [markdown]
# ##### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

param_grid = {'C': np.logspace(-4, 4, 20)}

logreg = LogisticRegression(max_iter=1000)

grid = GridSearchCV(logreg, param_grid, cv=10, scoring='neg_mean_squared_error')
grid.fit(X_train_scaled, y_train)

print(f"Best parameters for Logistic Regression: {grid.best_params_}")

best_logreg = grid.best_estimator_

# %% [markdown]
# ##### SVM

# %%
from sklearn.svm import SVR

param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001], 'kernel': ['rbf', 'poly', 'sigmoid']}

svm = SVR()

grid = GridSearchCV(svm, param_grid, cv=10, scoring='neg_mean_squared_error')
grid.fit(X_train_scaled, y_train)

print(f"Best parameters for SVM: {grid.best_params_}")

best_svm = grid.best_estimator_
